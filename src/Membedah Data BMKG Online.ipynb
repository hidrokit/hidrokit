# %% [markdown]
# Berhubung untuk data metadata stasiun sudah disertakan dalam `.bmkgkit`, akan langsung dipakai.

# %%
import numpy as np, pandas as pd, pathlib, matplotlib.pyplot as plt, seaborn as sns

# %%
# %load_ext autoreload
# %autoreload 2
# %aimport hidrokit
from hidrokit.bmkgkit import metadata_station

# %%
metadata_station.head()
# Out:
#      id_stat      name_stat            type_stat    region  \
# 0  11010101a       Bakongan  Pos Hujan Kerjasama  Region I
# 1  11010201a    Kluet Utara  Pos Hujan Kerjasama  Region I
# 2  11010301a  Kluet Selatan  Pos Hujan Kerjasama  Region I
# 3  11010401a   Labuhan Haji  Pos Hujan Kerjasama  Region I
# 4  11010501a         Meukek  Pos Hujan Kerjasama  Region I
#
#                    provinsi          kabupaten  lintang_derajat  \
# 0  Nanggroe Aceh Darussalam  Kab. Aceh Selatan          2.95000
# 1  Nanggroe Aceh Darussalam  Kab. Aceh Selatan          3.59000
# 2  Nanggroe Aceh Darussalam  Kab. Aceh Selatan          3.03000
# 3  Nanggroe Aceh Darussalam  Kab. Aceh Selatan          3.54000
# 4  Nanggroe Aceh Darussalam  Kab. Aceh Selatan          3.54321
#
#    bujur_derajat  ketinggian_mdpl  soil  exposure  land_use time_zone
# 0        97.4700                0   NaN       NaN       NaN    +07:00
# 1        97.0000                0   NaN       NaN       NaN       NaN
# 2        97.3800                0   NaN       NaN       NaN       NaN
# 3        97.0100                0   NaN       NaN       NaN       NaN
# 4        97.1523                0   NaN       NaN       NaN       NaN

# %% [markdown]
# rasanya tidak perlu digunakan kolom `ketinggian.mdpl soil exposure land.use time.zone`

# %%
metadata_station = metadata_station.drop(['ketinggian_mdpl', 'soil', 'exposure', 'land_use', 'time_zone'], axis=1)

# %%
metadata_station.head()
# Out:
#      id_stat      name_stat            type_stat    region  \
# 0  11010101a       Bakongan  Pos Hujan Kerjasama  Region I
# 1  11010201a    Kluet Utara  Pos Hujan Kerjasama  Region I
# 2  11010301a  Kluet Selatan  Pos Hujan Kerjasama  Region I
# 3  11010401a   Labuhan Haji  Pos Hujan Kerjasama  Region I
# 4  11010501a         Meukek  Pos Hujan Kerjasama  Region I
#
#                    provinsi          kabupaten  lintang_derajat  bujur_derajat
# 0  Nanggroe Aceh Darussalam  Kab. Aceh Selatan          2.95000        97.4700
# 1  Nanggroe Aceh Darussalam  Kab. Aceh Selatan          3.59000        97.0000
# 2  Nanggroe Aceh Darussalam  Kab. Aceh Selatan          3.03000        97.3800
# 3  Nanggroe Aceh Darussalam  Kab. Aceh Selatan          3.54000        97.0100
# 4  Nanggroe Aceh Darussalam  Kab. Aceh Selatan          3.54321        97.1523

# %% [markdown]
# Mari kita cek, data yang ada di bmkgonline

# %%
print(metadata_station.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8028 entries, 0 to 8027
# Data columns (total 8 columns):
# id_stat            8028 non-null object
# name_stat          8028 non-null object
# type_stat          8028 non-null object
# region             8028 non-null object
# provinsi           8028 non-null object
# kabupaten          8028 non-null object
# lintang_derajat    8028 non-null float64
# bujur_derajat      8028 non-null float64
# dtypes: float64(2), object(6)
# memory usage: 564.5+ KB
# None

# %%
print('Jumlah baris yang terdapat dalam metadata: ', metadata_station.shape[0])
# Out:
# Jumlah baris yang terdapat dalam metadata:  8028

# %%
print('Jumlah stasiun yang terdata di bmkg (berdasarkan id): ', metadata_station.id_stat.nunique())
print('Jumlah stasiun yang terdata di bmkg (berdasarkan nama): ', metadata_station.name_stat.nunique())
# Out:
# Jumlah stasiun yang terdata di bmkg (berdasarkan id):  8025
# Jumlah stasiun yang terdata di bmkg (berdasarkan nama):  7147

# %% [markdown]
# Angkanya berbeda, yang seharusnya sama. Dugaan saya adalah, ada stasiun yang tidak memiliki `id`. Atau ada beberapa stasiun yang memiliki `id` serupa (mungkin kah itu?). Tidak mungkin ada nilai `null` / `nan`, karena dari info, diketahui bahwa semua kolom merupakan `non-null`.

# %%
print('Check id stasiun yang sama')
print(metadata_station.id_stat.value_counts(ascending=False).head(5))
id_stasiun_sama = metadata_station.id_stat.value_counts(ascending=False).iloc[:3].index.tolist()
# Out:
# Check id stasiun yang sama
# 33221801a    2
# 97504        2
# 51010404a    2
# 35240402a    1
# 35241801a    1
# Name: id_stat, dtype: int64

# %% [markdown]
# Ternyata ada 3 `id` stasiun yang menyimpan dua informasi stasiun. Stasiun tersebut

# %%
stasiun_sama_id = metadata_station.loc[metadata_station['id_stat'].isin(id_stasiun_sama),:]
stasiun_sama_id
# Out:
#         id_stat                 name_stat            type_stat      region  \
# 2418  33221801a           Ungaran / Genuk  Pos Hujan Kerjasama   Region II
# 2455  33221801a           Ungaran / Genuk  Pos Hujan Kerjasama   Region II
# 4250  51010404a                  Nusasari  Pos Hujan Kerjasama  Region III
# 4251  51010404a                   Tetelan  Pos Hujan Kerjasama  Region III
# 7231      97504  Stasiun Geofisika Sorong                  UPT    Region V
# 7232      97504  Stasiun Geofisika Sorong                  UPT    Region V
#
#          provinsi      kabupaten  lintang_derajat  bujur_derajat
# 2418  Jawa Tengah  Kab. Semarang         -7.14651       110.4057
# 2455  Jawa Tengah  Kab. Semarang         -7.14651       110.4057
# 4250         Bali  Kab. Jembrana         -8.28000       114.5100
# 4251         Bali  Kab. Jembrana         -8.29000       114.5100
# 7231  Papua Barat    Kota Sorong         -0.86000       131.2600
# 7232  Papua Barat    Kota Sorong         -0.86000       131.2600

# %%
def sama_atau_tidak(posisi1):
    posisi2 = posisi1+1
    mask = (~(stasiun_sama_id.iloc[posisi1] == stasiun_sama_id.iloc[posisi2]))
    id_stat = stasiun_sama_id.iloc[posisi1,0]
    total_yang_tidak_sama = mask.sum()
    if total_yang_tidak_sama:
        return (f'stasiun {id_stat} sama dengan stasiun berikutnya? \n\t'
                f'tidak, pada kolom {(mask[mask == True]).index.tolist()}')
    else:
        return (f'stasiun {id_stat} sama dengan stasiun berikutnya? \n\t'
                f'iya')
    
print(sama_atau_tidak(0))
print(sama_atau_tidak(2))
print(sama_atau_tidak(4))
# Out:
# stasiun 33221801a sama dengan stasiun berikutnya?
# 	iya
# stasiun 51010404a sama dengan stasiun berikutnya?
# 	tidak, pada kolom ['name_stat', 'lintang_derajat']
# stasiun 97504 sama dengan stasiun berikutnya?
# 	iya

# %% [markdown]
# Stasiun yang memiliki informasi yang sama akan dihapus dalam tabel

# %%
metadata_station = metadata_station.drop_duplicates(subset='id_stat', keep='first').reset_index(drop=True)

# %%
metadata_station.reset_index()
# Out:
#       index    id_stat                         name_stat            type_stat  \
# 0         0  11010101a                          Bakongan  Pos Hujan Kerjasama
# 1         1  11010201a                       Kluet Utara  Pos Hujan Kerjasama
# 2         2  11010301a                     Kluet Selatan  Pos Hujan Kerjasama
# 3         3  11010401a                      Labuhan Haji  Pos Hujan Kerjasama
# 4         4  11010501a                            Meukek  Pos Hujan Kerjasama
# 5         5  11010601a                          Sama Dua  Pos Hujan Kerjasama
# 6         6  11010701a                            Sawang  Pos Hujan Kerjasama
# 7         7  11010801a                        Tapak Tuan  Pos Hujan Kerjasama
# 8         8  11010901a                            Trumon  Pos Hujan Kerjasama
# 9         9  11011001a                        Pasie Raja  Pos Hujan Kerjasama
# 10       10  11011101a                Labuhan Haji Timur  Pos Hujan Kerjasama
# 11       11  11011301a                      Kluet Tengah  Pos Hujan Kerjasama
# 12       12  11011401a                       Kluet Timur  Pos Hujan Kerjasama
# 13       13  11011501a                    Bakongan Timur  Pos Hujan Kerjasama
# 14       14  11011601a                      Trumon Timur  Pos Hujan Kerjasama
# 15       15  11100101a                      Pulau Banyak  Pos Hujan Kerjasama
# 16       16  11100201a                     Simpang Kanan  Pos Hujan Kerjasama
# 17       17  11100401a                           Singkil  Pos Hujan Kerjasama
# 18       18  11101001a                     Singkil Utara  Pos Hujan Kerjasama
# 19       19  11101101a                       Danau Paris  Pos Hujan Kerjasama
# 20       20  11101201a                  Suro Baru/Makmur  Pos Hujan Kerjasama
# 21       21  11101301a                         Singkohor  Pos Hujan Kerjasama
# 22       22  11101401a                        Kuala Baru  Pos Hujan Kerjasama
# 23       23  11110501a                       Kota Baharu  Pos Hujan Kerjasama
# 24       24  11100402g                   AWS MES Singkil                  aws
# 25       25  11100601a                     Gunung Meriah  Pos Hujan Kerjasama
# 26       26  11100901a                       Kota Baharu  Pos Hujan Kerjasama
# 27       27  16020504h                          AAWS OKI                  aws
# 28       28  16020201a                     Tanjung Lubuk  Pos Hujan Kerjasama
# 29       29  16020301a                         Pedamaran  Pos Hujan Kerjasama
# ...     ...        ...                               ...                  ...
# 7995   7995  15090901a                       Tengah Ilir  Pos Hujan Kerjasama
# 7996   7996  15091001a                    Serai Serumpun  Pos Hujan Kerjasama
# 7997   7997  15091101a                   Tujuh Koto Ilir  Pos Hujan Kerjasama
# 7998   7998  15091201a                       Muara Tabir  Pos Hujan Kerjasama
# 7999   7999  15090302b                      ARG Tebo Ulu                  aws
# 8000   8000  15090502b                         ARG Sumay                  aws
# 8001   8001  15091102g               AWS Tujuh Koto Ilir                  aws
# 8002   8002      96195  Stasiun Meteorologi Sultan Thaha                  UPT
# 8003   8003  15710203g                  AWS Stamet Jambi                  aws
# 8004   8004  15710101a                    Simp.III Sipin  Pos Hujan Kerjasama
# 8005   8005  15710201a        Jambi Selatan/Stamet Jambi  Pos Hujan Kerjasama
# 8006   8006  15710301a                         Sijenjang  Pos Hujan Kerjasama
# 8007   8007  15710401a                       Pasar Jambi  Pos Hujan Kerjasama
# 8008   8008  15710501a                        Pelayangan  Pos Hujan Kerjasama
# 8009   8009  15710601a                       Olak Kemang  Pos Hujan Kerjasama
# 8010   8010  15710701a                         Kota Baru  Pos Hujan Kerjasama
# 8011   8011  15710801a                          Jelutung  Pos Hujan Kerjasama
# 8012   8012  15710202b                  ARG Stamet Jambi                  aws
# 8013   8013  15720101a                      Sungai Penuh  Pos Hujan Kerjasama
# 8014   8014  15720201a                     Pesisir Bukit  Pos Hujan Kerjasama
# 8015   8015  15720301a                   Hamparan Rawang  Pos Hujan Kerjasama
# 8016   8016  15720401a                     Tanah Kampung  Pos Hujan Kerjasama
# 8017   8017  15720501a                       Kumun Dubai  Pos Hujan Kerjasama
# 8018   8018  16012102b                           ARG OKU                  aws
# 8019   8019  16010801a                       Pengandonan  Pos Hujan Kerjasama
# 8020   8020  16010901a                        Peninjauan  Pos Hujan Kerjasama
# 8021   8021  16011401a                        Pasar Lama  Pos Hujan Kerjasama
# 8022   8022  16011402a                     Baturajatimur  Pos Hujan Kerjasama
# 8023   8023  16012201a                      Lubuk Batang  Pos Hujan Kerjasama
# 8024   8024  16012801a                      Karang Endah  Pos Hujan Kerjasama
#
#          region                  provinsi                kabupaten  \
# 0      Region I  Nanggroe Aceh Darussalam        Kab. Aceh Selatan
# 1      Region I  Nanggroe Aceh Darussalam        Kab. Aceh Selatan
# 2      Region I  Nanggroe Aceh Darussalam        Kab. Aceh Selatan
# 3      Region I  Nanggroe Aceh Darussalam        Kab. Aceh Selatan
# 4      Region I  Nanggroe Aceh Darussalam        Kab. Aceh Selatan
# 5      Region I  Nanggroe Aceh Darussalam        Kab. Aceh Selatan
# 6      Region I  Nanggroe Aceh Darussalam        Kab. Aceh Selatan
# 7      Region I  Nanggroe Aceh Darussalam        Kab. Aceh Selatan
# 8      Region I  Nanggroe Aceh Darussalam        Kab. Aceh Selatan
# 9      Region I  Nanggroe Aceh Darussalam        Kab. Aceh Selatan
# 10     Region I  Nanggroe Aceh Darussalam        Kab. Aceh Selatan
# 11     Region I  Nanggroe Aceh Darussalam        Kab. Aceh Selatan
# 12     Region I  Nanggroe Aceh Darussalam        Kab. Aceh Selatan
# 13     Region I  Nanggroe Aceh Darussalam        Kab. Aceh Selatan
# 14     Region I  Nanggroe Aceh Darussalam        Kab. Aceh Selatan
# 15     Region I  Nanggroe Aceh Darussalam        Kab. Aceh Singkil
# 16     Region I  Nanggroe Aceh Darussalam        Kab. Aceh Singkil
# 17     Region I  Nanggroe Aceh Darussalam        Kab. Aceh Singkil
# 18     Region I  Nanggroe Aceh Darussalam        Kab. Aceh Singkil
# 19     Region I  Nanggroe Aceh Darussalam        Kab. Aceh Singkil
# 20     Region I  Nanggroe Aceh Darussalam        Kab. Aceh Singkil
# 21     Region I  Nanggroe Aceh Darussalam        Kab. Aceh Singkil
# 22     Region I  Nanggroe Aceh Darussalam        Kab. Aceh Singkil
# 23     Region I  Nanggroe Aceh Darussalam        Kab. Aceh Singkil
# 24     Region I  Nanggroe Aceh Darussalam        Kab. Aceh Singkil
# 25     Region I  Nanggroe Aceh Darussalam        Kab. Aceh Singkil
# 26     Region I  Nanggroe Aceh Darussalam        Kab. Aceh Singkil
# 27    Region II          Sumatera Selatan  Kab. Ogan Komering Ilir
# 28    Region II          Sumatera Selatan  Kab. Ogan Komering Ilir
# 29    Region II          Sumatera Selatan  Kab. Ogan Komering Ilir
# ...         ...                       ...                      ...
# 7995  Region II                     Jambi                Kab. Tebo
# 7996  Region II                     Jambi                Kab. Tebo
# 7997  Region II                     Jambi                Kab. Tebo
# 7998  Region II                     Jambi                Kab. Tebo
# 7999  Region II                     Jambi                Kab. Tebo
# 8000  Region II                     Jambi                Kab. Tebo
# 8001  Region II                     Jambi                Kab. Tebo
# 8002  Region II                     Jambi               Kota Jambi
# 8003  Region II                     Jambi               Kota Jambi
# 8004  Region II                     Jambi               Kota Jambi
# 8005  Region II                     Jambi               Kota Jambi
# 8006  Region II                     Jambi               Kota Jambi
# 8007  Region II                     Jambi               Kota Jambi
# 8008  Region II                     Jambi               Kota Jambi
# 8009  Region II                     Jambi               Kota Jambi
# 8010  Region II                     Jambi               Kota Jambi
# 8011  Region II                     Jambi               Kota Jambi
# 8012  Region II                     Jambi               Kota Jambi
# 8013  Region II                     Jambi        Kota Sungai Penuh
# 8014  Region II                     Jambi        Kota Sungai Penuh
# 8015  Region II                     Jambi        Kota Sungai Penuh
# 8016  Region II                     Jambi        Kota Sungai Penuh
# 8017  Region II                     Jambi        Kota Sungai Penuh
# 8018  Region II          Sumatera Selatan   Kab. Ogan Komering Ulu
# 8019  Region II          Sumatera Selatan   Kab. Ogan Komering Ulu
# 8020  Region II          Sumatera Selatan   Kab. Ogan Komering Ulu
# 8021  Region II          Sumatera Selatan   Kab. Ogan Komering Ulu
# 8022  Region II          Sumatera Selatan   Kab. Ogan Komering Ulu
# 8023  Region II          Sumatera Selatan   Kab. Ogan Komering Ulu
# 8024  Region II          Sumatera Selatan   Kab. Ogan Komering Ulu
#
#       lintang_derajat  bujur_derajat
# 0             2.95000       97.47000
# 1             3.59000       97.00000
# 2             3.03000       97.38000
# 3             3.54000       97.01000
# 4             3.54321       97.15230
# 5             3.32000       97.14000
# 6             3.39000       97.11000
# 7             3.27000       97.21000
# 8             2.88000       97.67000
# 9             3.25000       97.28000
# 10            3.52000       97.03000
# 11            3.51000       97.35000
# 12            3.23000       97.43000
# 13            2.91000       97.55000
# 14            2.82000       97.76000
# 15            2.19000       97.28000
# 16            2.45000       98.04000
# 17            2.29000       97.85000
# 18            2.28000       97.94000
# 19            2.47000       97.85000
# 20            2.54000       98.05000
# 21            2.53000       97.94000
# 22            2.37000       97.75000
# 23            2.43000       97.82000
# 24            2.27530       97.95480
# 25            2.29000       98.14000
# 26            2.43000       97.82000
# 27           -4.40750      105.44100
# 28           -3.53008      104.75780
# 29           -3.49606      104.83630
# ...               ...            ...
# 7995         -1.48272      102.65850
# 7996         -1.44940      102.24120
# 7997         -1.25606      102.14140
# 7998         -1.65675      102.57580
# 7999         -1.22885      102.24310
# 8000         -1.37814      102.42845
# 8001         -1.17837      102.15579
# 8002         -1.63368      103.64000
# 8003         -1.63439      103.55081
# 8004         -1.62003      103.58560
# 8005         -1.63439      103.55080
# 8006         -1.63439      103.55080
# 8007         -1.59700      103.60190
# 8008         -1.56947      103.62079
# 8009         -1.56922      103.57740
# 8010         -1.63439      103.55080
# 8011         -1.60400      103.60900
# 8012         -1.63370      103.55080
# 8013         -2.09133      101.39170
# 8014         -2.03831      101.37150
# 8015         -2.02360      101.24260
# 8016         -2.04262      101.26090
# 8017         -2.05322      101.25020
# 8018         -4.76706      103.97150
# 8019         -4.45156      103.87490
# 8020         -3.81340      104.34392
# 8021         -4.20150      104.28390
# 8022         -4.13278      104.19770
# 8023         -4.02342      104.23560
# 8024         -4.34992      104.11040
#
# [8025 rows x 9 columns]

# %% [markdown]
# Bagaimana dengan kolom `nama`?

# %%
nama_stasiun_sama = metadata_station.name_stat.value_counts()
print(nama_stasiun_sama.head(5),'\n')
print('25 stasiun yang muncul lebih dari satu kali: \n\t',
      ', '.join(nama_stasiun_sama[nama_stasiun_sama != 1].index.tolist()[:25]))
print()
print('Jumlah nama yang memiliki id stasiun lebih dari 1: \n\t',
      (nama_stasiun_sama != 1).sum())
# Out:
# Karanganyar    6
# Sidomulyo      5
# Tanjung        5
# Sukadana       5
# Ciawi          4
# Name: name_stat, dtype: int64
#
# 25 stasiun yang muncul lebih dari satu kali:
# 	 Karanganyar, Sidomulyo, Tanjung, Sukadana, Ciawi, Guguk, Wonorejo, Koto Baru, Talawi, Sungai Tarab, Lambuya, Bojong, Babadan, Rembang, Cubadak, Cinangka, Curug, Blimbing, Beji, Ombilin, Sukamaju, Lengkong, Bakung, Sukaraja, Ketapang
#
# Jumlah nama yang memiliki id stasiun lebih dari 1:
# 	 788

# %% [markdown]
# Ternyata ada beberapa stasiun yang memiliki nama yang sama, meski memiliki `id` yang berbeda. Karena `id` merupakan identitas utama dari stasiun, maka untuk `nama` yang sama diabaikan.

# %% [markdown]
# Data akan disimpan dalam `.csv` dengan nama `clean_metadata_station`

# %%
metadata_station.to_csv('clean_metadata_station.csv', index=False)

# %%
metadata_station.groupby('type_stat').count()
# Out:
#                      id_stat  name_stat  region  provinsi  kabupaten  \
# type_stat
# Pos Hujan Kerjasama     6993       6993    6993      6993       6993
# UPT                      179        179     179       179        179
# aws                      853        853     853       853        853
#
#                      lintang_derajat  bujur_derajat
# type_stat
# Pos Hujan Kerjasama             6993           6993
# UPT                              179            179
# aws                              853            853

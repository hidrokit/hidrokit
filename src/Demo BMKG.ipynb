# %%
# %load_ext autoreload

# %%
# %autoreload 2
# %aimport hidrokit

# %%
from hidrokit.bmkgkit import metadata_station

# %%
mask = metadata_station['kabupaten'] == 'Kota Bandung'
metadata_station[mask]
# Out:
#         id.stat                  name.stat            type.stat     region    ...     soil exposure  land.use  time.zone
# 1659      96783  Stasiun Geofisika Bandung                  UPT  Region II    ...      NaN      NaN       NaN     +07:00
# 1660  32730701g        AWS Stageof Bandung                  aws  Region II    ...      NaN      NaN       NaN        NaN
# 1661  32730501a               Lanud Husein  Pos Hujan Kerjasama  Region II    ...      NaN      NaN       NaN        NaN
# 1662  32730601a                    Cicendo  Pos Hujan Kerjasama  Region II    ...      NaN      NaN       NaN        NaN
# 1663  32730801a                    Bengkok  Pos Hujan Kerjasama  Region II    ...      NaN      NaN       NaN        NaN
# 1664  32731301a               Tekaga Bodas  Pos Hujan Kerjasama  Region II    ...      NaN      NaN       NaN        NaN
# 1665  33010102a     Lengkong/ Telaga Bodas  Pos Hujan Kerjasama  Region II    ...      NaN      NaN       NaN        NaN
# ...

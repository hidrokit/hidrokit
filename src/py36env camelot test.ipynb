# %%
import pandas as pd
import pathlib
import camelot

# %%
filepath = '../testdata/pdf/citarum_testdata/13. Cibiru.pdf'

# %%
tables = camelot.read_pdf(filepath, pages='1', flavor='stream')

# %%
tables[0].parsing_report
# Out:
# {'accuracy': 98.15, 'whitespace': 48.9, 'order': 1, 'page': 1}

# %%
df_raw = tables[0].df

# %%
df_raw
# Out:
#                                    0  1   \
# 0
# 1                        Nama Stasiun
# 2                          No Stasiun  -
# 3                      No In Database  -
# 4                     Lintang Selatan
# 5                         Bujur Timur
# 6                               Tahun
# 7                             Tanggal
# 8
# 9                                   1
# 10                                  2
# 11                                  3
# 12                                  4
# 13                                  5
# 14                                  6
# 15                                  7
# 16                                  8
# 17                                  9
# 18                                 10
# 19                                 11
# 20                                 12
# 21                                 13
# 22                                 14
# 23                                 15
# 24                                 16
# ...

# %%
a = df_raw.iloc[9:40,2:]
a.drop([6,9], axis=1, inplace=True)
a
# Out:
#       2     3     4     5     7  8  10 11   12    13    14    15
# 9   24.0   6.0  16.0   3.5     -  -  -  -    -     -     -     -
# 10     -   8.0  16.0   6.5   3.0  -  -  -    -     -     -   7.0
# 11  11.0   0.0  25.0   3.0  77.5  -  -  -    -     -     -   1.0
# 12   7.0   5.5     -     -  16.5  -  -  -    -     -     -   2.0
# 13   1.0   7.0   2.0  39.0  13.5  -  -  -    -     -     -     -
# 14     -  11.0   1.0     -   0.0  -  -  -    -     -  17.0  27.5
# 15     -   2.0     -   1.5   TAD  -  -  -    -  25.0   0.0   8.5
# 16     -  13.0   0.0     -     -  -  -  -    -     -   0.0  21.0
# 17     -   1.0   2.0  28.0     -  -  -  -    -     -  19.0  19.0
# 18     -  15.0     -  31.0     -  -  -  -    -     -  40.0   9.0
# 19     -   8.0     -     -     -  -  -  -    -     -   1.0  12.5
# 20     -  23.0   9.0   3.0     -  -  -  -    -     -   7.5   2.5
# 21   0.0  26.5   7.5  54.5     -  -  -  -    -     -   0.0   3.5
# ...

# %%
from hidrokit import prepkit

# %%
a.shape
# Out:
# (31, 12)

# %%
prepkit.tf_rawdf(a, 2001)
# Out:
#               ch
# date
# 2001-01-01  24.0
# 2001-01-02     -
# 2001-01-03  11.0
# 2001-01-04   7.0
# 2001-01-05   1.0
# 2001-01-06     -
# 2001-01-07     -
# 2001-01-08     -
# 2001-01-09     -
# 2001-01-10     -
# 2001-01-11     -
# 2001-01-12     -
# 2001-01-13   0.0
# 2001-01-14   5.5
# 2001-01-15   0.0
# 2001-01-16   1.0
# 2001-01-17     -
# 2001-01-18     -
# 2001-01-19   0.0
# 2001-01-20   1.5
# 2001-01-21  19.0
# 2001-01-22   1.5
# 2001-01-23   5.0
# 2001-01-24   5.0
# 2001-01-25   5.0
# 2001-01-26   7.5
# 2001-01-27   0.0
# 2001-01-28   4.0
# 2001-01-29   5.0
# 2001-01-30  11.5
# ...          ...
# 2001-12-02   7.0
# 2001-12-03   1.0
# 2001-12-04   2.0
# 2001-12-05     -
# 2001-12-06  27.5
# 2001-12-07   8.5
# 2001-12-08  21.0
# 2001-12-09  19.0
# 2001-12-10   9.0
# 2001-12-11  12.5
# 2001-12-12   2.5
# 2001-12-13   3.5
# 2001-12-14  35.5
# 2001-12-15  16.0
# 2001-12-16  17.0
# 2001-12-17     -
# 2001-12-18     -
# 2001-12-19     -
# 2001-12-20     -
# 2001-12-21   1.5
# ...
